# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import scipy
import numpy as np

def fft_plot(audio, sampling_rate):
  n=len(audio)
  T=1/sampling_rate
  yf=scipy.fft (audio)
  xf=np.linspace(0.0, 1.0/(2.0*T), int(n/2))
  fig, ax = plt.subplots()
  ax.plot(xf,2.0/n*np.abs (yf[:n//2]))
  plt.grid()
  plt.xlabel("Frequency -->")
  plt.ylabel("Magnitude")
  return plt.show()

# %% [markdown]
# **Orignal input audio**

# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display

audio = '/content/drive/MyDrive/Colab Notebooks/OWL/Neutral_SF9_F1_N01.wav'

x, sr = librosa.load(audio)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize = (10, 5))
librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')
plt.colorbar()

# %%
plt.figure()
librosa.display.waveplot(y=x, sr=sr)
plt.xlabel("Time (second)")
plt.ylabel("Amplitude")
plt.show()

# %%
fft_plot(x,sr)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Using scipy.fft as a function is deprecated and will be removed in SciPy 1.5.0, use scipy.fft.fft instead.
#   import sys

# %% [markdown]
# **Translated Audio**

# %%
audio = '/content/drive/MyDrive/Colab Notebooks/OWL/bot.wav'

x, sr = librosa.load(audio)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize = (10, 5))
librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')
plt.colorbar()

# %%
plt.figure()
librosa.display.waveplot(y=x, sr=sr)
plt.xlabel("Time (second)")
plt.ylabel("Amplitude")
plt.show()

# %%
fft_plot(x,sr)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Using scipy.fft as a function is deprecated and will be removed in SciPy 1.5.0, use scipy.fft.fft instead.
#   import sys

# %% [markdown]
# **Ai bot voice cloning**

# %%
import librosa
import matplotlib.pyplot as plt
import librosa.display

audio = '/content/drive/MyDrive/Colab Notebooks/OWL/bot (1).wav'

x, sr = librosa.load(audio)
X = librosa.stft(x)
Xdb = librosa.amplitude_to_db(abs(X))
plt.figure(figsize = (10, 5))
librosa.display.specshow(Xdb, sr = sr, x_axis = 'time', y_axis = 'hz')
plt.colorbar()

# %%
plt.figure()
librosa.display.waveplot(y=x, sr=sr)
plt.xlabel("Time (second)")
plt.ylabel("Amplitude")
plt.show()

# %%
fft_plot(x,sr)
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:7: DeprecationWarning: Using scipy.fft as a function is deprecated and will be removed in SciPy 1.5.0, use scipy.fft.fft instead.
#   import sys
